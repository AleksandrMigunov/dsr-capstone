# %% [markdown]
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2021-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/M1_R_Basics/images/IDSNlogo.png" width="200" align="center">
# </a>

# %% [markdown]
# <h1>Refine the Baseline Regression Models</h1>
#
# Estimated time needed: **120** minutes

# %% [markdown]
# ## Lab Overview:
#
# Now you have built a baseline regression model with some relatively good RMSE and R-squared reported values. However, we could still improve it by using methods like adding polynomial and interaction terms, regularization, and so on.
#
# In this lab, you will be asked to continue using `tidymodels` to improve the performance of baseline model:
#
# *   **TASK: Add polynomial terms**
# *   **TASK: Add interactions terms**
# *   **TASK: Add regularizations terms**
# *   **TASK: Experiment to search for improved models**
#
# Let's start!

# %% [markdown]
# First install and import necessary libraries

# %%
# Check whether you need to install `rlang` and `tidymodels` libraries
#install.packages("rlang")
#install.packages("tidymodels")

# %%
library("tidymodels")
library("tidyverse")
library("stringr")
# Out:
# Registered S3 method overwritten by 'tune':
#   method                   from
#   required_pkgs.model_spec parsnip
#
# ── Attaching packages ────────────────────────────────────── tidymodels 0.1.4 ──
#
# ✔ broom        0.7.12     ✔ recipes      0.1.17
# ✔ dials        0.1.0      ✔ rsample      0.1.1
# ✔ dplyr        1.0.7      ✔ tibble       3.1.6
# ✔ ggplot2      3.3.5      ✔ tidyr        1.1.4
# ✔ infer        1.0.0      ✔ tune         0.1.6
# ✔ modeldata    0.1.1      ✔ workflows    0.2.4
# ✔ parsnip      0.1.7      ✔ workflowsets 0.1.0
# ✔ purrr        0.3.4      ✔ yardstick    0.0.9
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ purrr::discard() masks scales::discard()
# ✖ dplyr::filter()  masks stats::filter()
# ✖ dplyr::lag()     masks stats::lag()
# ✖ recipes::step()  masks stats::step()
# • Dig deeper into tidy modeling with R at https://www.tmwr.org
#
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ readr   2.1.2     ✔ forcats 0.5.1
# ✔ stringr 1.4.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ readr::col_factor() masks scales::col_factor()
# ✖ purrr::discard()    masks scales::discard()
# ✖ dplyr::filter()     masks stats::filter()
# ✖ stringr::fixed()    masks recipes::fixed()
# ✖ dplyr::lag()        masks stats::lag()
# ✖ readr::spec()       masks yardstick::spec()

# %% [markdown]
# The processed Seoul bike sharing dataset `seoul_bike_sharing_converted_normalized.csv`,  includes the converted indicator variables, and the numerical variables have been normalized.
# Let's read it as a dataframe first:

# %%
# Dataset URL
dataset_url <- "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0321EN-SkillsNetwork/labs/datasets/seoul_bike_sharing_converted_normalized.csv"
bike_sharing_df <- read_csv(dataset_url)
spec(bike_sharing_df)
# Out:
# Rows: 8465 Columns: 41
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (2): DATE, FUNCTIONING_DAY
# dbl (39): RENTED_BIKE_COUNT, TEMPERATURE, HUMIDITY, WIND_SPEED, VISIBILITY, ...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# cols(
#   DATE = col_character(),
#   RENTED_BIKE_COUNT = col_double(),
#   TEMPERATURE = col_double(),
#   HUMIDITY = col_double(),
#   WIND_SPEED = col_double(),
#   VISIBILITY = col_double(),
#   DEW_POINT_TEMPERATURE = col_double(),
#   SOLAR_RADIATION = col_double(),
#   RAINFALL = col_double(),
#   SNOWFALL = col_double(),
#   FUNCTIONING_DAY = col_character(),
#   `0` = col_double(),
#   `1` = col_double(),
#   `10` = col_double(),
#   `11` = col_double(),
#   `12` = col_double(),
#   `13` = col_double(),
#   `14` = col_double(),
#   `15` = col_double(),
#   `16` = col_double(),
#   `17` = col_double(),
#   `18` = col_double(),
#   `19` = col_double(),
#   `2` = col_double(),
#   `20` = col_double(),
#   `21` = col_double(),
#   `22` = col_double(),
#   `23` = col_double(),
#   `3` = col_double(),
#   `4` = col_double(),
#   `5` = col_double(),
#   `6` = col_double(),
#   `7` = col_double(),
#   `8` = col_double(),
#   `9` = col_double(),
#   AUTUMN = col_double(),
#   SPRING = col_double(),
#   SUMMER = col_double(),
#   WINTER = col_double(),
#   HOLIDAY = col_double(),
#   NO_HOLIDAY = col_double()
# )

# %% [markdown]
# We won't be using the `DATE` column, because 'as is', it basically acts like an data entry index. (However, given more time, we could use the `DATE` colum to create a 'day of week' or 'isWeekend' column, which we might expect has an affect on preferred bike rental times.) We also do not need the `FUNCTIONAL DAY` column because it only has one distinct value remaining (`YES`) after missing value processing.

# %%
bike_sharing_df <- bike_sharing_df %>% 
                   select(-DATE, -FUNCTIONING_DAY)

# %% [markdown]
# Define a linear regression model specification.

# %%
lm_spec <- linear_reg() %>%
  set_engine("lm") %>% 
  set_mode("regression")

# %% [markdown]
# Split the data into training and testing datasets.

# %%
set.seed(1234)
data_split <- initial_split(bike_sharing_df, prop = 4/5)
train_data <- training(data_split)
test_data <- testing(data_split)

# %% [markdown]
# Now we are ready to refine the previous baseline regression model.

# %% [markdown]
# # TASK: Add polynomial terms

# %% [markdown]
# Linear regression models are the most suitable models to capture the linear correlations among variables. However, in real world data, many relationships may be non-linear.

# %% [markdown]
# For example, the correlation between `RENTED_BIKE_COUNT` and `TEMPERATURE` does not look like linear:

# %%
ggplot(data = train_data, aes(RENTED_BIKE_COUNT, TEMPERATURE)) + 
    geom_point()
# Out:
# plot without title

# %% [raw]
# One solution to handle such nonlinearity is using polynomial regression by adding polynomial terms. As shown before, higher order polynomials are better than the first order polynomial.

# %%
# Plot the higher order polynomial fits
ggplot(data=train_data, aes(RENTED_BIKE_COUNT, TEMPERATURE)) + 
    geom_point() + 
    geom_smooth(method = "lm", formula = y ~ x, color="red") + 
    geom_smooth(method = "lm", formula = y ~ poly(x, 2), color="yellow") + 
    geom_smooth(method = "lm", formula = y ~ poly(x, 4), color="green") + 
    geom_smooth(method = "lm", formula = y ~ poly(x, 6), color="blue")
# Out:
# plot without title

# %% [markdown]
# OK, let's add some higher order polynomials of important variables to the regression models

# %% [markdown]
# *TODO:* Fit a linear regression model `lm_poly` with higher order polynomial terms on the important variables (larger coefficients) found in the baseline model

# %%
# Fit a linear model with higher order polynomial on some important variables 

# #HINT: Use ploy function to build polynomial terms, lm_poly <- RENTED_BIKE_COUNT ~ poly(TEMPERATURE, 6) + 
##poly(HUMIDITY, 4) .....

lm_poly <- lm_spec %>%
  fit(RENTED_BIKE_COUNT ~ poly(TEMPERATURE, 6) + poly(HUMIDITY, 4) + poly(WIND_SPEED, 4) + poly(VISIBILITY, 8) +
      poly(DEW_POINT_TEMPERATURE, 4) + poly(SOLAR_RADIATION, 6) + poly(RAINFALL, 6) + poly(SNOWFALL, 6), 
      data = train_data)

# %%
# Print model summary

# summary(lm_poly$fit)
summary(lm_poly$fit)
# Out:
# Call:
# stats::lm(formula = RENTED_BIKE_COUNT ~ poly(TEMPERATURE, 6) +
#     poly(HUMIDITY, 4) + poly(WIND_SPEED, 4) + poly(VISIBILITY,
#     8) + poly(DEW_POINT_TEMPERATURE, 4) + poly(SOLAR_RADIATION,
#     6) + poly(RAINFALL, 6) + poly(SNOWFALL, 6), data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1487.78  -238.83   -41.19   191.67  1879.19
#
# Coefficients:
#                                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)                        734.851      5.089 144.391  < 2e-16 ***
# poly(TEMPERATURE, 6)1            63450.358   5592.328  11.346  < 2e-16 ***
# poly(TEMPERATURE, 6)2             8667.691    893.768   9.698  < 2e-16 ***
# poly(TEMPERATURE, 6)3           -10916.075    598.975 -18.225  < 2e-16 ***
# poly(TEMPERATURE, 6)4            -6753.360    545.496 -12.380  < 2e-16 ***
# poly(TEMPERATURE, 6)5              127.884    473.582   0.270 0.787141
# poly(TEMPERATURE, 6)6              721.809    433.901   1.664 0.096252 .
# poly(HUMIDITY, 4)1               -4304.136   2683.725  -1.604 0.108807
# poly(HUMIDITY, 4)2               -4346.911    668.597  -6.502 8.52e-11 ***
# poly(HUMIDITY, 4)3                 267.407    503.191   0.531 0.595143
# poly(HUMIDITY, 4)4               -1577.908    579.788  -2.722 0.006515 **
# poly(WIND_SPEED, 4)1              4384.864    470.387   9.322  < 2e-16 ***
# poly(WIND_SPEED, 4)2             -2958.523    431.702  -6.853 7.87e-12 ***
# poly(WIND_SPEED, 4)3             -1461.223    424.512  -3.442 0.000581 ***
# poly(WIND_SPEED, 4)4              1285.868    422.357   3.045 0.002340 **
# poly(VISIBILITY, 8)1               692.427    562.011   1.232 0.217972
# poly(VISIBILITY, 8)2               -91.093    462.036  -0.197 0.843712
# poly(VISIBILITY, 8)3             -1027.858    437.280  -2.351 0.018773 *
# poly(VISIBILITY, 8)4               794.654    431.370   1.842 0.065496 .
# poly(VISIBILITY, 8)5                63.790    429.065   0.149 0.881817
# poly(VISIBILITY, 8)6              -454.781    424.162  -1.072 0.283674
# poly(VISIBILITY, 8)7               102.472    423.089   0.242 0.808633
# poly(VISIBILITY, 8)8              -382.600    421.620  -0.907 0.364200
# poly(DEW_POINT_TEMPERATURE, 4)1 -31746.318   6598.863  -4.811 1.54e-06 ***
# poly(DEW_POINT_TEMPERATURE, 4)2 -18356.135    918.257 -19.990  < 2e-16 ***
# poly(DEW_POINT_TEMPERATURE, 4)3  -3421.935    618.565  -5.532 3.28e-08 ***
# poly(DEW_POINT_TEMPERATURE, 4)4   2289.330    549.599   4.165 3.15e-05 ***
# poly(SOLAR_RADIATION, 6)1       -10770.858    630.030 -17.096  < 2e-16 ***
# poly(SOLAR_RADIATION, 6)2        -7580.661    443.904 -17.077  < 2e-16 ***
# poly(SOLAR_RADIATION, 6)3         5813.413    422.860  13.748  < 2e-16 ***
# poly(SOLAR_RADIATION, 6)4        -3107.414    422.337  -7.358 2.09e-13 ***
# poly(SOLAR_RADIATION, 6)5         3403.545    422.000   8.065 8.58e-16 ***
# poly(SOLAR_RADIATION, 6)6        -1743.163    422.434  -4.126 3.73e-05 ***
# poly(RAINFALL, 6)1               -3486.968    491.903  -7.089 1.49e-12 ***
# poly(RAINFALL, 6)2                2834.912    457.867   6.192 6.31e-10 ***
# poly(RAINFALL, 6)3               -2474.547    446.524  -5.542 3.11e-08 ***
# poly(RAINFALL, 6)4                1979.403    433.825   4.563 5.14e-06 ***
# poly(RAINFALL, 6)5               -1857.245    427.752  -4.342 1.43e-05 ***
# poly(RAINFALL, 6)6                1711.459    426.426   4.013 6.05e-05 ***
# poly(SNOWFALL, 6)1                -244.284    469.044  -0.521 0.602514
# poly(SNOWFALL, 6)2                 389.820    436.409   0.893 0.371758
# poly(SNOWFALL, 6)3                -442.733    447.857  -0.989 0.322915
# poly(SNOWFALL, 6)4                 219.139    449.751   0.487 0.626100
# poly(SNOWFALL, 6)5                 123.586    442.743   0.279 0.780148
# poly(SNOWFALL, 6)6                -318.942    429.439  -0.743 0.457692
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 418.8 on 6727 degrees of freedom
# Multiple R-squared:  0.5806,	Adjusted R-squared:  0.5778
# F-statistic: 211.6 on 44 and 6727 DF,  p-value: < 2.2e-16

# %% [markdown]
# *TODO:* Make predictions on test dataset using the `lm_poly` models

# %%
# Use predict() function to generate test results for `lm_poly`
test_results <- lm_poly %>%
  predict(new_data = test_data) %>%
  mutate(truth = test_data$RENTED_BIKE_COUNT)
#head(test_results)

# %% [markdown]
# Another minor improvement we could do here is to convert all negative prediction results to zero, because we can not have negative rented bike counts

# %%
# e.g., test_results[test_results<0] <- 0
test_results[test_results<0] <- 0

# %% [markdown]
# Now, calculate R-squared and RMSE for the test results generated by `lm_ploy` model

# %%
# Calculate R-squared and RMSE from the test results
rsq(test_results, truth = truth,
    estimate = .pred)
rmse(test_results, truth = truth,
     estimate = .pred)
# Out:
#   .metric .estimator .estimate
# 1 rsq     standard   0.5800577
#   .metric .estimator .estimate
# 1 rmse    standard   410.2241

# %% [markdown]
# If you include all variables, and additionally include some of the more important ones as higher order poly terms, then you should notice improved  `R-squared` and `RMSE` values.

# %% [markdown]
# # TASK: Add interaction terms

# %% [markdown]
# In real-world scenarios, in addition to non-linear relationships between response variables and predictor variables, you may also encounter relationships among variables called `interaction effects`.
#
# For example, the effect of predictor variable `TEMPERATURE` on `RENTED_BIKE_COUNT` may also depend on other variables such as `HUMIDITY`, `RAINFALL`, or both (they `interact`) and the effect of `SEASON` on `RENTED_BIKE_COUNT` may also depend on `HOLIDAY`, `HOUR`, or both.
#
# To capture such interaction effects, we could add some interaction terms such as `RAINFALL*HUMIDITY` to the regression model, similar to what we did with polynominal terms. In this task, you will explore and conduct some experiments to search for interaction terms which will improve the model performance.

# %% [markdown]
# *TODO:* Try adding some interaction terms to the previous polynomial models.

# %%
# Add interaction terms to the poly regression built in previous step

# HINT: You could use `*` operator to create interaction terms such as HUMIDITY*TEMPERATURE and make the formula look like:
# RENTED_BIKE_COUNT ~ RAINFALL*HUMIDITY ...
lm_poly1 <- lm_spec %>%
  fit(RENTED_BIKE_COUNT ~ poly(TEMPERATURE, 6) + poly(HUMIDITY, 4) + poly(WIND_SPEED, 4) + poly(VISIBILITY, 8) +
      poly(DEW_POINT_TEMPERATURE, 4) + poly(SOLAR_RADIATION, 6) + poly(RAINFALL, 6) + poly(SNOWFALL, 6) +
      HUMIDITY*TEMPERATURE + RAINFALL*HUMIDITY + TEMPERATURE*WIND_SPEED + TEMPERATURE*VISIBILITY +
      TEMPERATURE*DEW_POINT_TEMPERATURE + TEMPERATURE*SOLAR_RADIATION + TEMPERATURE*RAINFALL + TEMPERATURE*SNOWFALL +
      HUMIDITY*WIND_SPEED + HUMIDITY*VISIBILITY + HUMIDITY*DEW_POINT_TEMPERATURE + HUMIDITY*SOLAR_RADIATION +
      HUMIDITY*SNOWFALL + WIND_SPEED*VISIBILITY + WIND_SPEED*DEW_POINT_TEMPERATURE + WIND_SPEED*SOLAR_RADIATION +
      WIND_SPEED*RAINFALL + WIND_SPEED*SNOWFALL + VISIBILITY*DEW_POINT_TEMPERATURE + VISIBILITY*SOLAR_RADIATION +
      VISIBILITY*RAINFALL + VISIBILITY*SNOWFALL + DEW_POINT_TEMPERATURE*SOLAR_RADIATION + 
      DEW_POINT_TEMPERATURE*RAINFALL + DEW_POINT_TEMPERATURE*SNOWFALL + SOLAR_RADIATION*RAINFALL + 
      SOLAR_RADIATION*SNOWFALL + RAINFALL*SNOWFALL, data = train_data)

# %%
# Print model summary
summary(lm_poly1$fit)
# Out:
# Call:
# stats::lm(formula = RENTED_BIKE_COUNT ~ poly(TEMPERATURE, 6) +
#     poly(HUMIDITY, 4) + poly(WIND_SPEED, 4) + poly(VISIBILITY,
#     8) + poly(DEW_POINT_TEMPERATURE, 4) + poly(SOLAR_RADIATION,
#     6) + poly(RAINFALL, 6) + poly(SNOWFALL, 6) + HUMIDITY * TEMPERATURE +
#     RAINFALL * HUMIDITY + TEMPERATURE * WIND_SPEED + TEMPERATURE *
#     VISIBILITY + TEMPERATURE * DEW_POINT_TEMPERATURE + TEMPERATURE *
#     SOLAR_RADIATION + TEMPERATURE * RAINFALL + TEMPERATURE *
#     SNOWFALL + HUMIDITY * WIND_SPEED + HUMIDITY * VISIBILITY +
#     HUMIDITY * DEW_POINT_TEMPERATURE + HUMIDITY * SOLAR_RADIATION +
#     HUMIDITY * SNOWFALL + WIND_SPEED * VISIBILITY + WIND_SPEED *
#     DEW_POINT_TEMPERATURE + WIND_SPEED * SOLAR_RADIATION + WIND_SPEED *
#     RAINFALL + WIND_SPEED * SNOWFALL + VISIBILITY * DEW_POINT_TEMPERATURE +
#     VISIBILITY * SOLAR_RADIATION + VISIBILITY * RAINFALL + VISIBILITY *
#     SNOWFALL + DEW_POINT_TEMPERATURE * SOLAR_RADIATION + DEW_POINT_TEMPERATURE *
#     RAINFALL + DEW_POINT_TEMPERATURE * SNOWFALL + SOLAR_RADIATION *
#     RAINFALL + SOLAR_RADIATION * SNOWFALL + RAINFALL * SNOWFALL,
#     data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1510.29  -219.18   -38.16   169.86  1976.72
#
# Coefficients: (8 not defined because of singularities)
#                                         Estimate Std. Error t value Pr(>|t|)
# (Intercept)                               317.15    2743.70   0.116 0.907980
# poly(TEMPERATURE, 6)1                   33560.94   63543.18   0.528 0.597406
# poly(TEMPERATURE, 6)2                  -15360.54   13501.73  -1.138 0.255298
# poly(TEMPERATURE, 6)3                  -11043.38     719.77 -15.343  < 2e-16
# poly(TEMPERATURE, 6)4                   -5847.86     558.86 -10.464  < 2e-16
# poly(TEMPERATURE, 6)5                     272.65     479.87   0.568 0.569937
# poly(TEMPERATURE, 6)6                    1252.62     431.98   2.900 0.003747
# poly(HUMIDITY, 4)1                      27356.19   16086.63   1.701 0.089073
# poly(HUMIDITY, 4)2                      -8760.01    2503.57  -3.499 0.000470
# poly(HUMIDITY, 4)3                       1838.09     943.83   1.947 0.051518
# poly(HUMIDITY, 4)4                      -2619.88     679.32  -3.857 0.000116
# poly(WIND_SPEED, 4)1                    13517.31    5133.41   2.633 0.008478
# poly(WIND_SPEED, 4)2                    -2334.65     472.50  -4.941 7.96e-07
# poly(WIND_SPEED, 4)3                    -1842.45     429.43  -4.290 1.81e-05
# poly(WIND_SPEED, 4)4                      546.51     422.25   1.294 0.195618
# poly(VISIBILITY, 8)1                    13714.79    6315.67   2.172 0.029925
# poly(VISIBILITY, 8)2                     -904.15     552.58  -1.636 0.101835
# poly(VISIBILITY, 8)3                     -648.28     452.43  -1.433 0.151935
# poly(VISIBILITY, 8)4                      763.28     428.67   1.781 0.075031
# poly(VISIBILITY, 8)5                      300.76     422.83   0.711 0.476927
# poly(VISIBILITY, 8)6                     -236.28     419.13  -0.564 0.572946
# poly(VISIBILITY, 8)7                      -32.70     416.39  -0.079 0.937413
# poly(VISIBILITY, 8)8                     -249.02     413.89  -0.602 0.547422
# poly(DEW_POINT_TEMPERATURE, 4)1        -69353.52   82608.36  -0.840 0.401193
# poly(DEW_POINT_TEMPERATURE, 4)2        -13432.12   16979.24  -0.791 0.428919
# poly(DEW_POINT_TEMPERATURE, 4)3         -3482.43     703.50  -4.950 7.60e-07
# poly(DEW_POINT_TEMPERATURE, 4)4          2200.65     556.39   3.955 7.73e-05
# poly(SOLAR_RADIATION, 6)1                1163.45    7858.76   0.148 0.882311
# poly(SOLAR_RADIATION, 6)2               -3070.02     623.39  -4.925 8.65e-07
# poly(SOLAR_RADIATION, 6)3                5824.10     429.40  13.563  < 2e-16
# poly(SOLAR_RADIATION, 6)4               -3264.25     416.73  -7.833 5.50e-15
# poly(SOLAR_RADIATION, 6)5                3019.52     415.68   7.264 4.18e-13
# poly(SOLAR_RADIATION, 6)6               -2066.68     414.62  -4.984 6.37e-07
# poly(RAINFALL, 6)1                     -41950.50   39425.77  -1.064 0.287350
# poly(RAINFALL, 6)2                       2452.15     580.07   4.227 2.40e-05
# poly(RAINFALL, 6)3                      -1980.67     481.87  -4.110 4.00e-05
# poly(RAINFALL, 6)4                       1690.54     455.55   3.711 0.000208
# poly(RAINFALL, 6)5                      -1556.61     444.93  -3.499 0.000471
# poly(RAINFALL, 6)6                       1826.18     442.57   4.126 3.73e-05
# poly(SNOWFALL, 6)1                      -8995.05    9467.71  -0.950 0.342107
# poly(SNOWFALL, 6)2                       -537.46     611.48  -0.879 0.379459
# poly(SNOWFALL, 6)3                        141.71     491.76   0.288 0.773227
# poly(SNOWFALL, 6)4                        207.09     529.14   0.391 0.695537
# poly(SNOWFALL, 6)5                       -254.71     512.69  -0.497 0.619338
# poly(SNOWFALL, 6)6                         43.11     451.59   0.095 0.923957
# HUMIDITY                                      NA         NA      NA       NA
# TEMPERATURE                                   NA         NA      NA       NA
# RAINFALL                                      NA         NA      NA       NA
# WIND_SPEED                                    NA         NA      NA       NA
# VISIBILITY                                    NA         NA      NA       NA
# DEW_POINT_TEMPERATURE                         NA         NA      NA       NA
# SOLAR_RADIATION                               NA         NA      NA       NA
# SNOWFALL                                      NA         NA      NA       NA
# HUMIDITY:TEMPERATURE                    -9814.92    2336.63  -4.200 2.70e-05
# HUMIDITY:RAINFALL                       -9004.23   48376.78  -0.186 0.852351
# TEMPERATURE:WIND_SPEED                     61.84    2001.86   0.031 0.975357
# TEMPERATURE:VISIBILITY                   1292.70    1502.38   0.860 0.389582
# TEMPERATURE:DEW_POINT_TEMPERATURE        6997.84    6989.14   1.001 0.316745
# TEMPERATURE:SOLAR_RADIATION              -766.32    1488.36  -0.515 0.606657
# TEMPERATURE:RAINFALL                  -125847.96  160221.10  -0.785 0.432209
# TEMPERATURE:SNOWFALL                     3260.90   11937.78   0.273 0.784740
# HUMIDITY:WIND_SPEED                     -3725.04    1042.50  -3.573 0.000355
# HUMIDITY:VISIBILITY                       575.63     662.65   0.869 0.385052
# HUMIDITY:DEW_POINT_TEMPERATURE           3880.52    2397.16   1.619 0.105537
# HUMIDITY:SOLAR_RADIATION                 2607.53     948.79   2.748 0.006007
# HUMIDITY:SNOWFALL                        2077.91    5014.93   0.414 0.678634
# WIND_SPEED:VISIBILITY                    -523.25     173.22  -3.021 0.002531
# WIND_SPEED:DEW_POINT_TEMPERATURE         3336.36    2175.14   1.534 0.125111
# WIND_SPEED:SOLAR_RADIATION              -1526.79     234.95  -6.498 8.71e-11
# RAINFALL:WIND_SPEED                       453.16    1235.36   0.367 0.713761
# WIND_SPEED:SNOWFALL                      2646.18    1251.42   2.115 0.034506
# VISIBILITY:DEW_POINT_TEMPERATURE        -2379.05    1597.56  -1.489 0.136489
# VISIBILITY:SOLAR_RADIATION                400.09     134.98   2.964 0.003046
# RAINFALL:VISIBILITY                       332.13     580.94   0.572 0.567544
# VISIBILITY:SNOWFALL                      -301.21     728.62  -0.413 0.679330
# DEW_POINT_TEMPERATURE:SOLAR_RADIATION   -1986.16    1635.73  -1.214 0.224700
# RAINFALL:DEW_POINT_TEMPERATURE         122517.36  163425.20   0.750 0.453471
# DEW_POINT_TEMPERATURE:SNOWFALL          -2121.14   12287.87  -0.173 0.862955
# RAINFALL:SOLAR_RADIATION               -11256.03    7073.47  -1.591 0.111589
# SOLAR_RADIATION:SNOWFALL                -2532.11    1673.61  -1.513 0.130337
# RAINFALL:SNOWFALL                        8749.58    7350.55   1.190 0.233959
#
# (Intercept)
# poly(TEMPERATURE, 6)1
# poly(TEMPERATURE, 6)2
# poly(TEMPERATURE, 6)3                 ***
# poly(TEMPERATURE, 6)4                 ***
# poly(TEMPERATURE, 6)5
# poly(TEMPERATURE, 6)6                 **
# poly(HUMIDITY, 4)1                    .
# poly(HUMIDITY, 4)2                    ***
# poly(HUMIDITY, 4)3                    .
# poly(HUMIDITY, 4)4                    ***
# poly(WIND_SPEED, 4)1                  **
# poly(WIND_SPEED, 4)2                  ***
# poly(WIND_SPEED, 4)3                  ***
# poly(WIND_SPEED, 4)4
# poly(VISIBILITY, 8)1                  *
# poly(VISIBILITY, 8)2
# poly(VISIBILITY, 8)3
# poly(VISIBILITY, 8)4                  .
# poly(VISIBILITY, 8)5
# poly(VISIBILITY, 8)6
# poly(VISIBILITY, 8)7
# poly(VISIBILITY, 8)8
# poly(DEW_POINT_TEMPERATURE, 4)1
# poly(DEW_POINT_TEMPERATURE, 4)2
# poly(DEW_POINT_TEMPERATURE, 4)3       ***
# poly(DEW_POINT_TEMPERATURE, 4)4       ***
# poly(SOLAR_RADIATION, 6)1
# poly(SOLAR_RADIATION, 6)2             ***
# poly(SOLAR_RADIATION, 6)3             ***
# poly(SOLAR_RADIATION, 6)4             ***
# poly(SOLAR_RADIATION, 6)5             ***
# poly(SOLAR_RADIATION, 6)6             ***
# poly(RAINFALL, 6)1
# poly(RAINFALL, 6)2                    ***
# poly(RAINFALL, 6)3                    ***
# poly(RAINFALL, 6)4                    ***
# poly(RAINFALL, 6)5                    ***
# poly(RAINFALL, 6)6                    ***
# poly(SNOWFALL, 6)1
# poly(SNOWFALL, 6)2
# poly(SNOWFALL, 6)3
# poly(SNOWFALL, 6)4
# poly(SNOWFALL, 6)5
# poly(SNOWFALL, 6)6
# HUMIDITY
# TEMPERATURE
# RAINFALL
# WIND_SPEED
# VISIBILITY
# DEW_POINT_TEMPERATURE
# SOLAR_RADIATION
# SNOWFALL
# HUMIDITY:TEMPERATURE                  ***
# HUMIDITY:RAINFALL
# TEMPERATURE:WIND_SPEED
# TEMPERATURE:VISIBILITY
# TEMPERATURE:DEW_POINT_TEMPERATURE
# TEMPERATURE:SOLAR_RADIATION
# TEMPERATURE:RAINFALL
# TEMPERATURE:SNOWFALL
# HUMIDITY:WIND_SPEED                   ***
# HUMIDITY:VISIBILITY
# HUMIDITY:DEW_POINT_TEMPERATURE
# HUMIDITY:SOLAR_RADIATION              **
# HUMIDITY:SNOWFALL
# WIND_SPEED:VISIBILITY                 **
# WIND_SPEED:DEW_POINT_TEMPERATURE
# WIND_SPEED:SOLAR_RADIATION            ***
# RAINFALL:WIND_SPEED
# WIND_SPEED:SNOWFALL                   *
# VISIBILITY:DEW_POINT_TEMPERATURE
# VISIBILITY:SOLAR_RADIATION            **
# RAINFALL:VISIBILITY
# VISIBILITY:SNOWFALL
# DEW_POINT_TEMPERATURE:SOLAR_RADIATION
# RAINFALL:DEW_POINT_TEMPERATURE
# DEW_POINT_TEMPERATURE:SNOWFALL
# RAINFALL:SOLAR_RADIATION
# SOLAR_RADIATION:SNOWFALL
# RAINFALL:SNOWFALL
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 408 on 6699 degrees of freedom
# Multiple R-squared:  0.6036,	Adjusted R-squared:  0.5993
# F-statistic: 141.7 on 72 and 6699 DF,  p-value: < 2.2e-16

# %%
test_results1 <- lm_poly1 %>%
  predict(new_data = test_data) %>%
  mutate(truth = test_data$RENTED_BIKE_COUNT)
#head(test_results1)
# Out:
# Warning message in predict.lm(object = object$fit, newdata = new_data, type = "response"):
# “prediction from a rank-deficient fit may be misleading”

# %%
# Calculate R-squared and RMSE for the new model to see if performance has improved
rsq(test_results1, truth = truth,
    estimate = .pred)
rmse(test_results1, truth = truth,
     estimate = .pred)
# Out:
#   .metric .estimator .estimate
# 1 rsq     standard   0.5900638
#   .metric .estimator .estimate
# 1 rmse    standard   405.2858

# %% [markdown]
# # TASK: Add regularization

# %% [markdown]
# In previous tasks, you were asked to add polynominal and interaction terms to the model, aiming to capture nonlinearity and interaction effects between the predictor variables. Hopefully, your updated models have better R-squared and RMSE values.
#
# However, adding these terms makes your model more complicated, more difficult to explain, and more likely to suffer from overfitting. To overcome these issues, one solution is to add regularization terms to your models.

# %% [markdown]
# When building the baseline model, we used the basic `lm` engine. In this task, you will use a more advanced and generalized `glmnet` engine. It provides a generalized linear model with Lasso, Ridge, and Elastic Net regularizations.
#
# In general, using `glmnet` can enhance your models in the following ways:
#
# *   Address overfitting issues by shrinking the coefficients
# *   Address predictor variable colinearity by selecting only one variable from each group of colinear variables (by shrinking their coefficients to zero)
# *   Make your models more interpretable due to simplification (fewer variables in the outcome models)

# %% [markdown]
# Now, let's switch our regression engine to `glmnet`

# %%
#install.packages('glmnet')
library('glmnet')
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘Matrix’
#
#
# The following objects are masked from ‘package:tidyr’:
#
#     expand, pack, unpack
#
#
# Loaded glmnet 4.1-3

# %%
#weather_recipe <-
#  recipe(RENTED_BIKE_COUNT ~ ., data = train_data)

# %%
rec <- 
  recipe(RENTED_BIKE_COUNT ~ ., data = train_data)

weather_recipe <- rec %>%
  step_poly(TEMPERATURE, HUMIDITY, WIND_SPEED, VISIBILITY, DEW_POINT_TEMPERATURE, SOLAR_RADIATION, RAINFALL, 
            SNOWFALL, degree=8)
weather_recipe <- prep(weather_recipe, data = train_data)

# %% [markdown]
# *TODO:* Define a linear regression model specification `glmnet_spec` using `glmnet` engine

# %%
# HINT: Use linear_reg() function with two parameters: penalty and mixture
# - penalty controls the intensity of model regularization
# - mixture controls the tradeoff between L1 and L2 regularizations

# You could manually try different parameter combinations or use grid search to find optimal combinations
glmnet_spec <- linear_reg(penalty = 0.1, mixture = 0) %>%   # ridge
  # Set engine
  set_engine("glmnet")

glmnet_spec1 <- linear_reg(penalty = 0.1, mixture = 1) %>%  # lasso
  # Set engine
  set_engine("glmnet")

glmnet_spec2 <- linear_reg(penalty = 0.1, mixture = 0.5) %>%  # elastic net
  # Set engine
  set_engine("glmnet")

# %% [markdown]
# Fit a glmnet model called  `lm_glmnet` using the `fit()` function. For the formula part, keep the polynominal and interaction terms you used in the previous task.

# %%
# Fit a glmnet model using the fit() function
ridge_wf <- workflow() %>%
  add_recipe(weather_recipe)
ridge_fit <- ridge_wf %>%
  add_model(glmnet_spec) %>%
  fit(data = train_data)
ridge_fit %>%
  extract_fit_parsnip() %>%
  tidy()
# Out:
#    term                         estimate    penalty
# 1  (Intercept)                   690.197929 0.1
# 2  0                              16.464052 0.1
# 3  1                             -92.762783 0.1
# 4  10                           -375.887982 0.1
# 5  11                           -324.868235 0.1
# 6  12                           -221.323091 0.1
# 7  13                           -214.171173 0.1
# 8  14                           -201.533053 0.1
# 9  15                           -149.334868 0.1
# 10 16                            -63.762432 0.1
# 11 17                            181.223807 0.1
# 12 18                            657.444809 0.1
# 13 19                            471.506448 0.1
# 14 2                            -195.350427 0.1
# 15 20                            450.184470 0.1
# 16 21                            476.430208 0.1
# 17 22                            363.618996 0.1
# 18 23                            132.127245 0.1
# 19 3                            -256.450847 0.1
# 20 4                            -332.642072 0.1
# 21 5                            -308.337256 0.1
# 22 6                            -170.690310 0.1
# 23 7                              39.267916 0.1
# 24 8                             266.709297 0.1
# 25 9                            -180.386367 0.1
# 26 AUTUMN                        137.185587 0.1
# 27 SPRING                         -9.159523 0.1
# 28 SUMMER                         92.241393 0.1
# 29 WINTER                       -213.662453 0.1
# 30 HOLIDAY                       -50.543123 0.1
# ⋮  ⋮                            ⋮           ⋮
# 66 DEW_POINT_TEMPERATURE_poly_3 -2762.75763 0.1
# 67 DEW_POINT_TEMPERATURE_poly_4   647.25007 0.1
# 68 DEW_POINT_TEMPERATURE_poly_5   585.12917 0.1
# 69 DEW_POINT_TEMPERATURE_poly_6  1100.46757 0.1
# 70 DEW_POINT_TEMPERATURE_poly_7   432.56691 0.1
# 71 DEW_POINT_TEMPERATURE_poly_8   715.29898 0.1
# 72 SOLAR_RADIATION_poly_1        8074.87716 0.1
# 73 SOLAR_RADIATION_poly_2       -8286.65363 0.1
# 74 SOLAR_RADIATION_poly_3        4576.84162 0.1
# 75 SOLAR_RADIATION_poly_4       -1921.58606 0.1
# 76 SOLAR_RADIATION_poly_5        2048.41722 0.1
# 77 SOLAR_RADIATION_poly_6        -352.35887 0.1
# 78 SOLAR_RADIATION_poly_7         896.04675 0.1
# 79 SOLAR_RADIATION_poly_8        -456.34038 0.1
# 80 RAINFALL_poly_1              -4459.35816 0.1
# 81 RAINFALL_poly_2               3078.69461 0.1
# 82 RAINFALL_poly_3              -1978.44456 0.1
# 83 RAINFALL_poly_4               2729.17970 0.1
# 84 RAINFALL_poly_5              -1916.41732 0.1
# 85 RAINFALL_poly_6               1853.87211 0.1
# 86 RAINFALL_poly_7              -1480.41306 0.1
# 87 RAINFALL_poly_8               1045.41000 0.1
# 88 SNOWFALL_poly_1               -393.77344 0.1
# 89 SNOWFALL_poly_2                378.18724 0.1
# 90 SNOWFALL_poly_3                 40.64008 0.1
# 91 SNOWFALL_poly_4               -525.82747 0.1
# 92 SNOWFALL_poly_5                368.80742 0.1
# 93 SNOWFALL_poly_6                350.74604 0.1
# 94 SNOWFALL_poly_7               -386.19868 0.1
# 95 SNOWFALL_poly_8               -547.12046 0.1

# %%
lasso_wf <- workflow() %>%
  add_recipe(weather_recipe)
lasso_fit <- lasso_wf %>%
  add_model(glmnet_spec1) %>%
  fit(data = train_data)
lasso_fit %>%
  extract_fit_parsnip() %>%
  tidy()
# Out:
#    term                         estimate     penalty
# 1  (Intercept)                   612.480459  0.1
# 2  0                             224.639434  0.1
# 3  1                             108.529439  0.1
# 4  10                           -359.817608  0.1
# 5  11                           -307.282059  0.1
# 6  12                           -196.876297  0.1
# 7  13                           -192.973980  0.1
# 8  14                           -185.929280  0.1
# 9  15                           -134.859730  0.1
# 10 16                            -39.612278  0.1
# 11 17                            231.655855  0.1
# 12 18                            781.704364  0.1
# 13 19                            642.297309  0.1
# 14 2                               0.319603  0.1
# 15 20                            671.366261  0.1
# 16 21                            712.593473  0.1
# 17 22                            591.388448  0.1
# 18 23                            347.008963  0.1
# 19 3                             -64.258046  0.1
# 20 4                            -142.796347  0.1
# 21 5                            -120.042966  0.1
# 22 6                              15.084574  0.1
# 23 7                             190.717299  0.1
# 24 8                             374.361112  0.1
# 25 9                            -138.589692  0.1
# 26 AUTUMN                        153.881620  0.1
# 27 SPRING                        -16.742229  0.1
# 28 SUMMER                         81.108043  0.1
# 29 WINTER                       -201.758034  0.1
# 30 HOLIDAY                       -96.933978  0.1
# ⋮  ⋮                            ⋮            ⋮
# 66 DEW_POINT_TEMPERATURE_poly_3  -1950.41595 0.1
# 67 DEW_POINT_TEMPERATURE_poly_4    669.19324 0.1
# 68 DEW_POINT_TEMPERATURE_poly_5    560.53996 0.1
# 69 DEW_POINT_TEMPERATURE_poly_6   1075.61802 0.1
# 70 DEW_POINT_TEMPERATURE_poly_7    267.07536 0.1
# 71 DEW_POINT_TEMPERATURE_poly_8    700.21324 0.1
# 72 SOLAR_RADIATION_poly_1        12866.63474 0.1
# 73 SOLAR_RADIATION_poly_2       -11994.49015 0.1
# 74 SOLAR_RADIATION_poly_3         6414.33149 0.1
# 75 SOLAR_RADIATION_poly_4        -3144.75696 0.1
# 76 SOLAR_RADIATION_poly_5         2928.64629 0.1
# 77 SOLAR_RADIATION_poly_6         -788.59579 0.1
# 78 SOLAR_RADIATION_poly_7         1430.81652 0.1
# 79 SOLAR_RADIATION_poly_8         -869.40080 0.1
# 80 RAINFALL_poly_1               -4255.66166 0.1
# 81 RAINFALL_poly_2                2912.55200 0.1
# 82 RAINFALL_poly_3               -1736.86618 0.1
# 83 RAINFALL_poly_4                2828.66787 0.1
# 84 RAINFALL_poly_5               -1849.58005 0.1
# 85 RAINFALL_poly_6                1789.63361 0.1
# 86 RAINFALL_poly_7               -1478.10740 0.1
# 87 RAINFALL_poly_8                 982.00361 0.1
# 88 SNOWFALL_poly_1                -592.21010 0.1
# 89 SNOWFALL_poly_2                 609.29033 0.1
# 90 SNOWFALL_poly_3                  13.54865 0.1
# 91 SNOWFALL_poly_4                -525.69380 0.1
# 92 SNOWFALL_poly_5                 369.90139 0.1
# 93 SNOWFALL_poly_6                 495.24621 0.1
# 94 SNOWFALL_poly_7                -370.61160 0.1
# 95 SNOWFALL_poly_8                -560.17212 0.1

# %%
elasticnet_wf <- workflow() %>%
  add_recipe(weather_recipe)
elasticnet_fit <- elasticnet_wf %>%
  add_model(glmnet_spec2) %>%
  fit(data = train_data)
elasticnet_fit %>%
  extract_fit_parsnip() %>%
  tidy()
# Out:
#    term                         estimate    penalty
# 1  (Intercept)                   567.368515 0.1
# 2  0                             215.404525 0.1
# 3  1                              99.334806 0.1
# 4  10                           -370.135394 0.1
# 5  11                           -317.708014 0.1
# 6  12                           -207.402005 0.1
# 7  13                           -203.485215 0.1
# 8  14                           -196.333182 0.1
# 9  15                           -145.154590 0.1
# 10 16                            -49.812140 0.1
# 11 17                            221.647174 0.1
# 12 18                            771.748402 0.1
# 13 19                            632.618764 0.1
# 14 2                              -6.933611 0.1
# 15 20                            661.944933 0.1
# 16 21                            703.277238 0.1
# 17 22                            582.124290 0.1
# 18 23                            337.813347 0.1
# 19 3                             -73.519284 0.1
# 20 4                            -152.039031 0.1
# 21 5                            -129.251333 0.1
# 22 6                               5.946801 0.1
# 23 7                             181.248016 0.1
# 24 8                             364.518095 0.1
# 25 9                            -148.750775 0.1
# 26 AUTUMN                        165.337130 0.1
# 27 SPRING                         -5.421845 0.1
# 28 SUMMER                         92.744161 0.1
# 29 WINTER                       -190.572343 0.1
# 30 HOLIDAY                       -53.673261 0.1
# ⋮  ⋮                            ⋮           ⋮
# 66 DEW_POINT_TEMPERATURE_poly_3  -1957.7300 0.1
# 67 DEW_POINT_TEMPERATURE_poly_4    674.3688 0.1
# 68 DEW_POINT_TEMPERATURE_poly_5    561.0960 0.1
# 69 DEW_POINT_TEMPERATURE_poly_6   1077.3564 0.1
# 70 DEW_POINT_TEMPERATURE_poly_7    268.2602 0.1
# 71 DEW_POINT_TEMPERATURE_poly_8    701.0111 0.1
# 72 SOLAR_RADIATION_poly_1        12911.9937 0.1
# 73 SOLAR_RADIATION_poly_2       -12006.4215 0.1
# 74 SOLAR_RADIATION_poly_3         6425.8614 0.1
# 75 SOLAR_RADIATION_poly_4        -3153.6301 0.1
# 76 SOLAR_RADIATION_poly_5         2935.2293 0.1
# 77 SOLAR_RADIATION_poly_6         -795.1799 0.1
# 78 SOLAR_RADIATION_poly_7         1435.3844 0.1
# 79 SOLAR_RADIATION_poly_8         -873.4052 0.1
# 80 RAINFALL_poly_1               -4254.2361 0.1
# 81 RAINFALL_poly_2                2912.9135 0.1
# 82 RAINFALL_poly_3               -1737.2349 0.1
# 83 RAINFALL_poly_4                2830.0549 0.1
# 84 RAINFALL_poly_5               -1850.3481 0.1
# 85 RAINFALL_poly_6                1790.0102 0.1
# 86 RAINFALL_poly_7               -1478.6377 0.1
# 87 RAINFALL_poly_8                 982.7288 0.1
# 88 SNOWFALL_poly_1                -589.7963 0.1
# 89 SNOWFALL_poly_2                 610.3567 0.1
# 90 SNOWFALL_poly_3                  15.7640 0.1
# 91 SNOWFALL_poly_4                -528.6433 0.1
# 92 SNOWFALL_poly_5                 372.9073 0.1
# 93 SNOWFALL_poly_6                 496.2905 0.1
# 94 SNOWFALL_poly_7                -370.8991 0.1
# 95 SNOWFALL_poly_8                -562.6639 0.1

# %%
test_results_ridge <- ridge_fit %>%
  # Make the predictions and save the predicted values
  predict(new_data = test_data) %>%
  # Create a new column to save the true values
  mutate(truth = test_data$RENTED_BIKE_COUNT)

# %%
test_results_lasso <- lasso_fit %>%
  # Make the predictions and save the predicted values
  predict(new_data = test_data) %>%
  # Create a new column to save the true values
  mutate(truth = test_data$RENTED_BIKE_COUNT)

# %%
test_results_elasticnet <- elasticnet_fit %>%
  # Make the predictions and save the predicted values
  predict(new_data = test_data) %>%
  # Create a new column to save the true values
  mutate(truth = test_data$RENTED_BIKE_COUNT)

# %%
# Report rsq and rmse of the `lm_glmnet` model
rsq(test_results_ridge, truth = truth,
    estimate = .pred)
rsq(test_results_lasso, truth = truth,
    estimate = .pred)
rsq(test_results_elasticnet, truth = truth,
    estimate = .pred)

rmse(test_results_ridge, truth = truth,
     estimate = .pred)
rmse(test_results_lasso, truth = truth,
     estimate = .pred)
rmse(test_results_elasticnet, truth = truth,
     estimate = .pred)
# Out:
#   .metric .estimator .estimate
# 1 rsq     standard   0.7645112
#   .metric .estimator .estimate
# 1 rsq     standard   0.7685309
#   .metric .estimator .estimate
# 1 rsq     standard   0.7685045
#   .metric .estimator .estimate
# 1 rmse    standard   308.2321
#   .metric .estimator .estimate
# 1 rmse    standard   304.6527
#   .metric .estimator .estimate
# 1 rmse    standard   304.6712

# %% [markdown]
# # TASK: Experiment to search for improved models

# %% [markdown]
# Now you understand some of the methods that you can use to try to improve your models.

# %% [markdown]
# *TODO:* Experiment by building and testing at least five different models. For each of your experiments, include polynomial terms, interaction terms, and one of the three regularizations we introduced.

# %%
# Build at least five different models using polynomial terms, interaction terms, and regularizations.
ridge_spec <- linear_reg(penalty = 1, mixture = 0) %>%   # ridge
  # Set engine
  set_engine("glmnet")

lasso_spec <- linear_reg(penalty = 1, mixture = 1) %>%  # lasso
  # Set engine
  set_engine("glmnet")

elasticnet_spec <- linear_reg(penalty = 1, mixture = 0.5) %>%  # elastic net
  # Set engine
  set_engine("glmnet")

elasticnet_spec1 <- linear_reg(penalty = 1, mixture = 0.3) %>%  # elastic net
  # Set engine
  set_engine("glmnet")

elasticnet_spec2 <- linear_reg(penalty = 1, mixture = 0.1) %>%  # elastic net
  # Set engine
  set_engine("glmnet")

# Save their rmse and rsq values

# %%
ridge_wf1 <- workflow() %>%
  add_recipe(weather_recipe)
ridge_fit1 <- ridge_wf1 %>%
  add_model(ridge_spec) %>%
  fit(data = train_data)
ridge_fit1 %>%
  extract_fit_parsnip() %>%
  tidy()
# Out:
#    term                         estimate    penalty
# 1  (Intercept)                   690.197929 1
# 2  0                              16.464052 1
# 3  1                             -92.762783 1
# 4  10                           -375.887982 1
# 5  11                           -324.868235 1
# 6  12                           -221.323091 1
# 7  13                           -214.171173 1
# 8  14                           -201.533053 1
# 9  15                           -149.334868 1
# 10 16                            -63.762432 1
# 11 17                            181.223807 1
# 12 18                            657.444809 1
# 13 19                            471.506448 1
# 14 2                            -195.350427 1
# 15 20                            450.184470 1
# 16 21                            476.430208 1
# 17 22                            363.618996 1
# 18 23                            132.127245 1
# 19 3                            -256.450847 1
# 20 4                            -332.642072 1
# 21 5                            -308.337256 1
# 22 6                            -170.690310 1
# 23 7                              39.267916 1
# 24 8                             266.709297 1
# 25 9                            -180.386367 1
# 26 AUTUMN                        137.185587 1
# 27 SPRING                         -9.159523 1
# 28 SUMMER                         92.241393 1
# 29 WINTER                       -213.662453 1
# 30 HOLIDAY                       -50.543123 1
# ⋮  ⋮                            ⋮           ⋮
# 66 DEW_POINT_TEMPERATURE_poly_3 -2762.75763 1
# 67 DEW_POINT_TEMPERATURE_poly_4   647.25007 1
# 68 DEW_POINT_TEMPERATURE_poly_5   585.12917 1
# 69 DEW_POINT_TEMPERATURE_poly_6  1100.46757 1
# 70 DEW_POINT_TEMPERATURE_poly_7   432.56691 1
# 71 DEW_POINT_TEMPERATURE_poly_8   715.29898 1
# 72 SOLAR_RADIATION_poly_1        8074.87716 1
# 73 SOLAR_RADIATION_poly_2       -8286.65363 1
# 74 SOLAR_RADIATION_poly_3        4576.84162 1
# 75 SOLAR_RADIATION_poly_4       -1921.58606 1
# 76 SOLAR_RADIATION_poly_5        2048.41722 1
# 77 SOLAR_RADIATION_poly_6        -352.35887 1
# 78 SOLAR_RADIATION_poly_7         896.04675 1
# 79 SOLAR_RADIATION_poly_8        -456.34038 1
# 80 RAINFALL_poly_1              -4459.35816 1
# 81 RAINFALL_poly_2               3078.69461 1
# 82 RAINFALL_poly_3              -1978.44456 1
# 83 RAINFALL_poly_4               2729.17970 1
# 84 RAINFALL_poly_5              -1916.41732 1
# 85 RAINFALL_poly_6               1853.87211 1
# 86 RAINFALL_poly_7              -1480.41306 1
# 87 RAINFALL_poly_8               1045.41000 1
# 88 SNOWFALL_poly_1               -393.77344 1
# 89 SNOWFALL_poly_2                378.18724 1
# 90 SNOWFALL_poly_3                 40.64008 1
# 91 SNOWFALL_poly_4               -525.82747 1
# 92 SNOWFALL_poly_5                368.80742 1
# 93 SNOWFALL_poly_6                350.74604 1
# 94 SNOWFALL_poly_7               -386.19868 1
# 95 SNOWFALL_poly_8               -547.12046 1

# %%
lasso_wf1 <- workflow() %>%
  add_recipe(weather_recipe)
lasso_fit1 <- lasso_wf1 %>%
  add_model(lasso_spec) %>%
  fit(data = train_data)
lasso_fit1 %>%
  extract_fit_parsnip() %>%
  tidy()
# Out:
#    term                         estimate     penalty
# 1  (Intercept)                   602.6684552 1
# 2  0                             204.0169425 1
# 3  1                              88.5537227 1
# 4  10                           -317.9765249 1
# 5  11                           -264.2738299 1
# 6  12                           -153.5443875 1
# 7  13                           -149.0686733 1
# 8  14                           -142.8615007 1
# 9  15                            -93.1714556 1
# 10 16                             -1.0618253 1
# 11 17                            258.2871869 1
# 12 18                            795.0862667 1
# 13 19                            639.6024806 1
# 14 2                              -9.8550213 1
# 15 20                            653.6536405 1
# 16 21                            689.7102450 1
# 17 22                            569.5019280 1
# 18 23                            325.5465322 1
# 19 3                             -75.7470849 1
# 20 4                            -154.5821559 1
# 21 5                            -131.4708835 1
# 22 6                               0.3239958 1
# 23 7                             190.5367906 1
# 24 8                             391.6030718 1
# 25 9                            -101.0434670 1
# 26 AUTUMN                        149.6776568 1
# 27 SPRING                        -11.9589923 1
# 28 SUMMER                         79.2856715 1
# 29 WINTER                       -196.7758875 1
# 30 HOLIDAY                       -93.9628646 1
# ⋮  ⋮                            ⋮            ⋮
# 66 DEW_POINT_TEMPERATURE_poly_3  -1963.7088  1
# 67 DEW_POINT_TEMPERATURE_poly_4    522.9686  1
# 68 DEW_POINT_TEMPERATURE_poly_5    515.8134  1
# 69 DEW_POINT_TEMPERATURE_poly_6    990.5774  1
# 70 DEW_POINT_TEMPERATURE_poly_7    245.4154  1
# 71 DEW_POINT_TEMPERATURE_poly_8    670.3589  1
# 72 SOLAR_RADIATION_poly_1        11027.1895  1
# 73 SOLAR_RADIATION_poly_2       -10985.3298  1
# 74 SOLAR_RADIATION_poly_3         5815.1919  1
# 75 SOLAR_RADIATION_poly_4        -2709.4688  1
# 76 SOLAR_RADIATION_poly_5         2609.0511  1
# 77 SOLAR_RADIATION_poly_6         -561.2755  1
# 78 SOLAR_RADIATION_poly_7         1205.1804  1
# 79 SOLAR_RADIATION_poly_8         -678.4903  1
# 80 RAINFALL_poly_1               -4291.6850  1
# 81 RAINFALL_poly_2                2899.1357  1
# 82 RAINFALL_poly_3               -1743.5232  1
# 83 RAINFALL_poly_4                2748.6298  1
# 84 RAINFALL_poly_5               -1814.8651  1
# 85 RAINFALL_poly_6                1768.2431  1
# 86 RAINFALL_poly_7               -1424.8275  1
# 87 RAINFALL_poly_8                 937.9623  1
# 88 SNOWFALL_poly_1                -460.5060  1
# 89 SNOWFALL_poly_2                 469.4350  1
# 90 SNOWFALL_poly_3                   0.0000  1
# 91 SNOWFALL_poly_4                -461.5976  1
# 92 SNOWFALL_poly_5                 315.3236  1
# 93 SNOWFALL_poly_6                 381.6888  1
# 94 SNOWFALL_poly_7                -307.0034  1
# 95 SNOWFALL_poly_8                -482.8630  1

# %%
elasticnet_wf1 <- workflow() %>%
  add_recipe(weather_recipe)
elasticnet_fit1 <- elasticnet_wf1 %>%
  add_model(elasticnet_spec) %>%
  fit(data = train_data)
elasticnet_fit1 %>%
  extract_fit_parsnip() %>%
  tidy()
# Out:
#    term                         estimate     penalty
# 1  (Intercept)                   562.6835870 1
# 2  0                             207.5092171 1
# 3  1                              91.7397157 1
# 4  10                           -349.6105926 1
# 5  11                           -296.6532076 1
# 6  12                           -186.1894805 1
# 7  13                           -181.9680100 1
# 8  14                           -175.1193439 1
# 9  15                           -124.5150151 1
# 10 16                            -30.5999551 1
# 11 17                            235.7060271 1
# 12 18                            779.3699085 1
# 13 19                            632.8545682 1
# 14 2                             -11.5325909 1
# 15 20                            655.2073618 1
# 16 21                            694.1723436 1
# 17 22                            573.4472988 1
# 18 23                            329.4424439 1
# 19 3                             -77.8052875 1
# 20 4                            -156.4600669 1
# 21 5                            -133.5245400 1
# 22 6                               0.2284852 1
# 23 7                             182.3461566 1
# 24 8                             373.5210380 1
# 25 9                            -130.6167825 1
# 26 AUTUMN                        162.7512564 1
# 27 SPRING                         -4.0682662 1
# 28 SUMMER                         91.8561227 1
# 29 WINTER                       -190.0001184 1
# 30 HOLIDAY                       -52.8175874 1
# ⋮  ⋮                            ⋮            ⋮
# 66 DEW_POINT_TEMPERATURE_poly_3  -1974.7165  1
# 67 DEW_POINT_TEMPERATURE_poly_4    604.4360  1
# 68 DEW_POINT_TEMPERATURE_poly_5    552.4347  1
# 69 DEW_POINT_TEMPERATURE_poly_6   1043.1328  1
# 70 DEW_POINT_TEMPERATURE_poly_7    262.2356  1
# 71 DEW_POINT_TEMPERATURE_poly_8    689.5172  1
# 72 SOLAR_RADIATION_poly_1        12076.6307  1
# 73 SOLAR_RADIATION_poly_2       -11541.3391  1
# 74 SOLAR_RADIATION_poly_3         6151.3178  1
# 75 SOLAR_RADIATION_poly_4        -2957.3330  1
# 76 SOLAR_RADIATION_poly_5         2791.0672  1
# 77 SOLAR_RADIATION_poly_6         -694.5399  1
# 78 SOLAR_RADIATION_poly_7         1336.2401  1
# 79 SOLAR_RADIATION_poly_8         -789.7671  1
# 80 RAINFALL_poly_1               -4273.6468  1
# 81 RAINFALL_poly_2                2911.0236  1
# 82 RAINFALL_poly_3               -1743.4228  1
# 83 RAINFALL_poly_4                2797.1058  1
# 84 RAINFALL_poly_5               -1837.7284  1
# 85 RAINFALL_poly_6                1782.4610  1
# 86 RAINFALL_poly_7               -1458.2580  1
# 87 RAINFALL_poly_8                 966.9731  1
# 88 SNOWFALL_poly_1                -537.8311  1
# 89 SNOWFALL_poly_2                 551.6822  1
# 90 SNOWFALL_poly_3                   0.0000  1
# 91 SNOWFALL_poly_4                -500.6547  1
# 92 SNOWFALL_poly_5                 347.9166  1
# 93 SNOWFALL_poly_6                 452.8449  1
# 94 SNOWFALL_poly_7                -349.9284  1
# 95 SNOWFALL_poly_8                -530.7568  1

# %%
elasticnet_wf2 <- workflow() %>%
  add_recipe(weather_recipe)
elasticnet_fit2 <- elasticnet_wf2 %>%
  add_model(elasticnet_spec1) %>%
  fit(data = train_data)
elasticnet_fit2 %>%
  extract_fit_parsnip() %>%
  tidy()
# Out:
#    term                         estimate     penalty
# 1  (Intercept)                   583.651221  1
# 2  0                             198.001259  1
# 3  1                              82.153354  1
# 4  10                           -374.991830  1
# 5  11                           -322.462801  1
# 6  12                           -212.231849  1
# 7  13                           -208.169010  1
# 8  14                           -200.982956  1
# 9  15                           -149.941934  1
# 10 16                            -55.178614  1
# 11 17                            214.133662  1
# 12 18                            761.007630  1
# 13 19                            618.588185  1
# 14 2                             -22.933898  1
# 15 20                            644.780188  1
# 16 21                            685.098491  1
# 17 22                            564.244075  1
# 18 23                            320.224419  1
# 19 3                             -89.283955  1
# 20 4                            -167.826190  1
# 21 5                            -144.910153  1
# 22 6                              -7.300198  1
# 23 7                             168.037694  1
# 24 8                             354.691066  1
# 25 9                            -154.596131  1
# 26 AUTUMN                        156.999499  1
# 27 SPRING                        -12.061411  1
# 28 SUMMER                         85.379876  1
# 29 WINTER                       -197.854891  1
# 30 HOLIDAY                       -50.712461  1
# ⋮  ⋮                            ⋮            ⋮
# 66 DEW_POINT_TEMPERATURE_poly_3  -1978.67039 1
# 67 DEW_POINT_TEMPERATURE_poly_4    650.94434 1
# 68 DEW_POINT_TEMPERATURE_poly_5    558.10178 1
# 69 DEW_POINT_TEMPERATURE_poly_6   1065.01862 1
# 70 DEW_POINT_TEMPERATURE_poly_7    268.81425 1
# 71 DEW_POINT_TEMPERATURE_poly_8    697.24922 1
# 72 SOLAR_RADIATION_poly_1        12558.79484 1
# 73 SOLAR_RADIATION_poly_2       -11790.91703 1
# 74 SOLAR_RADIATION_poly_3         6306.14027 1
# 75 SOLAR_RADIATION_poly_4        -3069.30776 1
# 76 SOLAR_RADIATION_poly_5         2873.17247 1
# 77 SOLAR_RADIATION_poly_6         -754.18249 1
# 78 SOLAR_RADIATION_poly_7         1391.98638 1
# 79 SOLAR_RADIATION_poly_8         -836.76845 1
# 80 RAINFALL_poly_1               -4262.74273 1
# 81 RAINFALL_poly_2                2914.08142 1
# 82 RAINFALL_poly_3               -1742.33182 1
# 83 RAINFALL_poly_4                2817.00383 1
# 84 RAINFALL_poly_5               -1846.89207 1
# 85 RAINFALL_poly_6                1788.33435 1
# 86 RAINFALL_poly_7               -1471.48761 1
# 87 RAINFALL_poly_8                 978.59105 1
# 88 SNOWFALL_poly_1                -563.42191 1
# 89 SNOWFALL_poly_2                 584.92514 1
# 90 SNOWFALL_poly_3                  10.27674 1
# 91 SNOWFALL_poly_4                -520.06158 1
# 92 SNOWFALL_poly_5                 365.25896 1
# 93 SNOWFALL_poly_6                 477.89970 1
# 94 SNOWFALL_poly_7                -362.09070 1
# 95 SNOWFALL_poly_8                -551.38161 1

# %%
elasticnet_wf3 <- workflow() %>%
  add_recipe(weather_recipe)
elasticnet_fit3 <- elasticnet_wf3 %>%
  add_model(elasticnet_spec2) %>%
  fit(data = train_data)
elasticnet_fit3 %>%
  extract_fit_parsnip() %>%
  tidy()
# Out:
#    term                         estimate     penalty
# 1  (Intercept)                   650.43197   1
# 2  0                             139.60804   1
# 3  1                              23.65496   1
# 4  10                           -445.26548   1
# 5  11                           -392.92695   1
# 6  12                           -282.85074   1
# 7  13                           -278.81991   1
# 8  14                           -271.51407   1
# 9  15                           -220.30120   1
# 10 16                           -125.07201   1
# 11 17                            146.74727   1
# 12 18                            695.75328   1
# 13 19                            556.59157   1
# 14 2                             -83.12073   1
# 15 20                            585.43319   1
# 16 21                            626.78840   1
# 17 22                            505.79553   1
# 18 23                            261.82724   1
# 19 3                            -149.78174   1
# 20 4                            -228.22927   1
# 21 5                            -205.47955   1
# 22 6                             -68.62183   1
# 23 7                             105.56270   1
# 24 8                             288.81649   1
# 25 9                            -224.29518   1
# 26 AUTUMN                        153.15124   1
# 27 SPRING                        -17.53232   1
# 28 SUMMER                         81.16270   1
# 29 WINTER                       -203.70092   1
# 30 HOLIDAY                       -49.36663   1
# ⋮  ⋮                            ⋮            ⋮
# 66 DEW_POINT_TEMPERATURE_poly_3  -1969.28304 1
# 67 DEW_POINT_TEMPERATURE_poly_4    701.68883 1
# 68 DEW_POINT_TEMPERATURE_poly_5    565.49146 1
# 69 DEW_POINT_TEMPERATURE_poly_6   1079.45369 1
# 70 DEW_POINT_TEMPERATURE_poly_7    273.64948 1
# 71 DEW_POINT_TEMPERATURE_poly_8    710.55534 1
# 72 SOLAR_RADIATION_poly_1        12896.12229 1
# 73 SOLAR_RADIATION_poly_2       -11979.38079 1
# 74 SOLAR_RADIATION_poly_3         6419.89106 1
# 75 SOLAR_RADIATION_poly_4        -3152.80656 1
# 76 SOLAR_RADIATION_poly_5         2934.18477 1
# 77 SOLAR_RADIATION_poly_6         -798.13890 1
# 78 SOLAR_RADIATION_poly_7         1436.59694 1
# 79 SOLAR_RADIATION_poly_8         -876.05415 1
# 80 RAINFALL_poly_1               -4258.27738 1
# 81 RAINFALL_poly_2                2920.44035 1
# 82 RAINFALL_poly_3               -1745.37527 1
# 83 RAINFALL_poly_4                2834.50610 1
# 84 RAINFALL_poly_5               -1856.67082 1
# 85 RAINFALL_poly_6                1795.08590 1
# 86 RAINFALL_poly_7               -1484.38857 1
# 87 RAINFALL_poly_8                 989.27175 1
# 88 SNOWFALL_poly_1                -594.17296 1
# 89 SNOWFALL_poly_2                 613.70482 1
# 90 SNOWFALL_poly_3                  23.70759 1
# 91 SNOWFALL_poly_4                -538.16510 1
# 92 SNOWFALL_poly_5                 380.15313 1
# 93 SNOWFALL_poly_6                 500.05358 1
# 94 SNOWFALL_poly_7                -377.01806 1
# 95 SNOWFALL_poly_8                -569.87481 1

# %%
test_results_ridge1 <- ridge_fit1 %>%
  # Make the predictions and save the predicted values
  predict(new_data = test_data) %>%
  # Create a new column to save the true values
  mutate(truth = test_data$RENTED_BIKE_COUNT)

# %%
test_results_lasso1 <- lasso_fit1 %>%
  # Make the predictions and save the predicted values
  predict(new_data = test_data) %>%
  # Create a new column to save the true values
  mutate(truth = test_data$RENTED_BIKE_COUNT)

# %%
test_results_elasticnet1 <- elasticnet_fit1 %>%
  # Make the predictions and save the predicted values
  predict(new_data = test_data) %>%
  # Create a new column to save the true values
  mutate(truth = test_data$RENTED_BIKE_COUNT)

# %%
test_results_elasticnet2 <- elasticnet_fit2 %>%
  # Make the predictions and save the predicted values
  predict(new_data = test_data) %>%
  # Create a new column to save the true values
  mutate(truth = test_data$RENTED_BIKE_COUNT)

# %%
test_results_elasticnet3 <- elasticnet_fit3 %>%
  # Make the predictions and save the predicted values
  predict(new_data = test_data) %>%
  # Create a new column to save the true values
  mutate(truth = test_data$RENTED_BIKE_COUNT)

# %%
rsq(test_results_ridge1, truth = truth,
    estimate = .pred)
rsq(test_results_lasso1, truth = truth,
    estimate = .pred)
rsq(test_results_elasticnet1, truth = truth,
    estimate = .pred)
rsq(test_results_elasticnet2, truth = truth,
    estimate = .pred)
rsq(test_results_elasticnet3, truth = truth,
    estimate = .pred)

rmse(test_results_ridge1, truth = truth,
     estimate = .pred)
rmse(test_results_lasso1, truth = truth,
     estimate = .pred)
rmse(test_results_elasticnet1, truth = truth,
     estimate = .pred)
rmse(test_results_elasticnet2, truth = truth,
     estimate = .pred)
rmse(test_results_elasticnet3, truth = truth,
     estimate = .pred)
# Out:
#   .metric .estimator .estimate
# 1 rsq     standard   0.7645112
#   .metric .estimator .estimate
# 1 rsq     standard   0.7688183
#   .metric .estimator .estimate
# 1 rsq     standard   0.768742
#   .metric .estimator .estimate
# 1 rsq     standard   0.7686181
#   .metric .estimator .estimate
# 1 rsq     standard   0.7684817
#   .metric .estimator .estimate
# 1 rmse    standard   308.2321
#   .metric .estimator .estimate
# 1 rmse    standard   304.561
#   .metric .estimator .estimate
# 1 rmse    standard   304.5503
#   .metric .estimator .estimate
# 1 rmse    standard   304.6139
#   .metric .estimator .estimate
# 1 rmse    standard   304.6862

# %%
# Save their rmse and rsq values
rsq_ridge = rsq(test_results_ridge, truth = truth,
    estimate = .pred)
rsq_lasso = rsq(test_results_lasso, truth = truth,
    estimate = .pred)
rsq_elasticnet = rsq(test_results_elasticnet, truth = truth,
    estimate = .pred)

rmse_ridge = rmse(test_results_ridge, truth = truth,
     estimate = .pred)
rmse_lasso = rmse(test_results_lasso, truth = truth,
     estimate = .pred)
rmse_elasticnet = rmse(test_results_elasticnet, truth = truth,
     estimate = .pred)

rsq_lm_poly = rsq(test_results, truth = truth,
    estimate = .pred)
rsq_lm_poly1 = rsq(test_results1, truth = truth,
    estimate = .pred)

rmse_lm_poly = rmse(test_results, truth = truth,
     estimate = .pred)
rmse_lm_poly1 = rmse(test_results1, truth = truth,
     estimate = .pred)

# %%
# Save their rmse and rsq values
rsq_ridge1 = rsq(test_results_ridge1, truth = truth,
    estimate = .pred)
rsq_lasso1 = rsq(test_results_lasso1, truth = truth,
    estimate = .pred)
rsq_elasticnet1 = rsq(test_results_elasticnet1, truth = truth,
    estimate = .pred)
rsq_elasticnet2 = rsq(test_results_elasticnet2, truth = truth,
    estimate = .pred)
rsq_elasticnet3 = rsq(test_results_elasticnet3, truth = truth,
    estimate = .pred)

rmse_ridge1 = rmse(test_results_ridge1, truth = truth,
     estimate = .pred)
rmse_lasso1 = rmse(test_results_lasso1, truth = truth,
     estimate = .pred)
rmse_elasticnet1 = rmse(test_results_elasticnet1, truth = truth,
     estimate = .pred)
rmse_elasticnet2 = rmse(test_results_elasticnet2, truth = truth,
     estimate = .pred)
rmse_elasticnet3 = rmse(test_results_elasticnet3, truth = truth,
     estimate = .pred)

# %%
model_names <- c("lm_poly", "lm_poly1", "ridge", "lasso", "elasticnet", "ridge1", "lasso1", "elasticnet1", 
                 "elasticnet2", "elasticnet3")
rsq_value <- c(rsq_lm_poly$.estimate, rsq_lm_poly1$.estimate, rsq_ridge$.estimate, rsq_lasso$.estimate, 
               rsq_elasticnet$.estimate, rsq_ridge1$.estimate, rsq_lasso1$.estimate, rsq_elasticnet1$.estimate, 
               rsq_elasticnet2$.estimate, rsq_elasticnet3$.estimate)
rmse_value <- c(rmse_lm_poly$.estimate,rmse_lm_poly1$.estimate, rmse_ridge$.estimate, rmse_lasso$.estimate, 
                rmse_elasticnet$.estimate, rmse_ridge1$.estimate, rmse_lasso1$.estimate, rmse_elasticnet1$.estimate, 
                rmse_elasticnet2$.estimate, rmse_elasticnet3$.estimate)
comparison_df <- data.frame(model_names, rsq_value, rmse_value)
comparison_df
# Out:
#    model_names rsq_value rmse_value
# 1  lm_poly     0.5800577 410.2241
# 2  lm_poly1    0.5900638 405.2858
# 3  ridge       0.7645112 308.2321
# 4  lasso       0.7685309 304.6527
# 5  elasticnet  0.7685045 304.6712
# 6  ridge1      0.7645112 308.2321
# 7  lasso1      0.7688183 304.5610
# 8  elasticnet1 0.7687420 304.5503
# 9  elasticnet2 0.7686181 304.6139
# 10 elasticnet3 0.7684817 304.6862

# %%
# Report the best performed 
#model in terms of rmse and rsq
## The best model in terms 
#of rsq is lasso1
rsq_lasso1
rmse_lasso1
# Out:
#   .metric .estimator .estimate
# 1 rsq     standard   0.7688183
#   .metric .estimator .estimate
# 1 rmse    standard   304.561

# %%
## The best model in terms 
#of rmse is elasticnet1
rsq_elasticnet1
rmse_elasticnet1
# Out:
#   .metric .estimator .estimate
# 1 rsq     standard   0.768742
#   .metric .estimator .estimate
# 1 rmse    standard   304.5503

# %% [markdown]
# Here are the performance requirements for your best model:
#
# *   The RMSE should be less than 330 (rougly 10% of the max value in test dataset)
# *   R-squared should be greater than 0.72

# %% [markdown]
# *TODO:* Visualize the saved RMSE and R-squared values using a grouped barchart

# %%
# HINT: Use ggplot() + geom_bar()
ggplot(comparison_df, aes(fill=model_names, y=rsq_value, x=factor(model_names))) + 
    geom_bar(position="dodge", stat="identity")
# Out:
# plot without title

# %%
ggplot(comparison_df, aes(fill=model_names, y=rmse_value, x=factor(model_names))) + 
    geom_bar(position="dodge", stat="identity")
# Out:
# plot without title

# %% [markdown]
# *TODO:* Create a Q-Q plot by plotting the distribution difference between the predictions generated by your best model and the true values on the test dataset.

# %%
# HINT: Use ggplot() +
    # stat_qq(aes(sample=truth), color='green') +
    # stat_qq(aes(sample=prediction), color='red')
ggplot() +
  stat_qq(aes(sample=test_results_lasso1$truth), color='green') +
  stat_qq(aes(sample=test_results_lasso1$.pred), color='red')
# Out:
# plot without title

# %%
# HINT: Use ggplot() +
    # stat_qq(aes(sample=truth), color='green') +
    # stat_qq(aes(sample=prediction), color='red')
ggplot() +
  stat_qq(aes(sample=test_results_elasticnet1$truth), color='green') +
  stat_qq(aes(sample=test_results_elasticnet1$.pred), color='red')
# Out:
# plot without title

# %% [markdown]
# One example of such Q-Q plot may look like this:

# %% [markdown]
# <a href="https://cognitiveclass.ai/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2021-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0321EN-SkillsNetwork/labs/module_4/images/example_qq_plot.png" width="600" align="center">
# </a>

# %% [markdown]
# # More model improvment methods beyond this course

# %% [markdown]
# In addition to the methods mentioned in this lab and previous data analysis courses, you could also explore to try the following methods yourself to see if they could improve model performance:
#
# *   Remove potential redundant variables. If two variables have extremly high correlated, it is possible that they are redundant and could be removed from the model to improve the performance.
# *   Remove some outliers. Linear regression models are very sensitive to outliers, you could try to remove some outliers to see if it would improve performance
# *   Apply logarithm transformation. In case variable distributions are not normal distribution such as log-normal distribution, you could apply logaritm transformation on the variable to make them more look like normal distribution. In addition, logarithm transformation helps capture the non-linear relationships.
#
# If you have time, you could research and try more methods by searching related research papers/articles, discussion forums, etc. If you know how to use other machine learning models with `Tidymodels` such as Neural Networks, Tree models, or Boosting models, you can also try and compare them with the linear regression models.

# %% [markdown]
# # Next Steps:

# %% [markdown]
# Great! You have improved your baseline model using polynomial terms, interaction terms, and regularizations, and have found your best model.
#
# Now it's time to build an interactive dashboard to provide more interactive user-interactions.

# %% [markdown]
# ## Authors
#
# <a href="https://www.linkedin.com/in/yan-luo-96288783/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkRP0321ENSkillsNetwork25371262-2021-01-01" target="_blank">Yan Luo</a>

# %% [markdown]
# ### Other Contributors
#
# Jeff Grossman

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By | Change Description      |
# | ----------------- | ------- | ---------- | ----------------------- |
# | 2021-04-08        | 1.0     | Yan        | Initial version created |
# |                   |         |            |                         |
# |                   |         |            |                         |
#
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
